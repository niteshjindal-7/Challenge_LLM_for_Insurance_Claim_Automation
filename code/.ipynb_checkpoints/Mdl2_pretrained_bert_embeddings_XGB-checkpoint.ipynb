# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import torch
import torch.nn as nn
import transformers
from transformers import BertModel
from transformers import AutoTokenizer
from torch.utils.data import Dataset
# from transformers import AutoModelForSequenceClassification
from torch.utils.data import DataLoader, TensorDataset
print(transformers.__version__)
# !pip install evaluate
import evaluate
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from transformers import AutoTokenizer, AutoModel
import xgboost as xgb
from sklearn.metrics import classification_report, confusion_matrix
# Out:
# 4.15.0
# 2023-07-05 02:56:30.486655: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# /home/nitesh/env/dev38/python38/lib/python3.8/site-packages/xgboost/compat.py:93: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# ## Data Loading

# %%
# df = pd.read_csv('insurance_synthetic_data.csv')
df  = pd.read_csv('../dataset/insurance_claims_data/insurance_claims.csv')
df = df.rename(columns = {'incident_class':'label'})
df = df.rename(columns = {'incident_description':'text'})
# display(df)
print("Claim Categories:", df.label.unique())


# Divide the data into train, validation, and test sets
train, test = train_test_split(df, test_size=0.2, random_state=42)
# val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# Print the sizes of the datasets
print("Training dataset size:", len(train))
print("Test dataset size:", len(test))


labelencoder = LabelEncoder()
labelencoder.fit(train['label'])
train["encoded_label"] = labelencoder.fit_transform(train['label'])
test["encoded_label"] = labelencoder.transform(test['label'])
print("Training data Examples: ")
display(train)
print("Test data Examples: ")
display(test)
# Out:
# Claim Categories: ['property' 'auto' 'health']
# Training dataset size: 24000
# Test dataset size: 6000
# Training data Examples:
# /tmp/ipykernel_32225/2093047390.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["encoded_label"] = labelencoder.fit_transform(train['label'])
# /tmp/ipykernel_32225/2093047390.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["encoded_label"] = labelencoder.transform(test['label'])
#           label  policy_num        patient_name        date  policy_claim_no  \
# 21753      auto      151393        Ava Williams  2023-02-15             9433
# 251      health      610541      Elijah Johnson  2023-03-01             9100
# 22941  property      651336          Mia Martin  2022-10-23             5130
# 618    property      721591        Olivia Allen  2023-04-18             7523
# 17090      auto      523298     Alexander White  2022-12-07             2030
# ...         ...         ...                 ...         ...              ...
# 29802    health      851474         Daniel Hall  2022-12-11             1044
# 5390   property      831608  Sebastian Williams  2023-01-15             5309
# 860        auto      682288           Ava Davis  2022-07-04             5500
# 15795      auto      645125           James Lee  2022-08-31             4689
# 23654  property      789355     Benjamin Miller  2022-11-02             3819
#
#                                                     text  claim_amount  \
# 21753  There wa an incident on 2023-02-15 where Vehic...          2851
# 251    There wa a critical sprain incident on 2023-03...         25912
# 22941  A significant incident took place on 2022-10-2...         94044
# 618    A severe [ Property Incident 11 ] took place o...         55573
# 17090  On 2022-12-07 , a minor collision occurred inv...         57898
# ...                                                  ...           ...
# 29802  There wa a motor vehicle accident on 2022-12-1...         84412
# 5390   A severe [ Property Incident 30 ] took place o...         65063
# 860    On 2022-07-04 , a minor collision occurred inv...         73324
# 15795  A tree falling incident took place on 2022-08-...          8726
# 23654  There wa a significant [ Property Incident 17 ...         44084
#
#       claim_status                              communication_history  \
# 21753  In Progress  We need to ass the impact and consequence of t...
# 251    In Progress  We need to establish preventive measure to avo...
# 22941     Approved  I am seeking reimbursement for the replacement...
# 618    In Progress  I would appreciate your guidance in understand...
# 17090       Denied  Please gather information on the impact of the...
# ...            ...                                                ...
# 29802  In Progress  I request a thorough investigation into the fa...
# 5390   In Progress  I request a detailed breakdown of the coverage...
# 860    In Progress  I would like to discus any legal implication o...
# 15795       Denied  I request a thorough analysis of the policy an...
# 23654  In Progress  I request a detailed breakdown of the coverage...
#
#        encoded_label
# 21753              0
# 251                1
# 22941              2
# 618                2
# 17090              0
# ...              ...
# 29802              1
# 5390               2
# 860                0
# 15795              0
# 23654              2
#
# [24000 rows x 10 columns]
# Test data Examples:
#           label  policy_num        patient_name        date  policy_claim_no  \
# 2308   property      283620    Charlotte Miller  2023-03-12             4716
# 22404    health      439665  Charlotte Anderson  2023-01-17             7540
# 23397  property      707259     Daniel Williams  2023-04-08             2917
# 25058    health      326420        Amelia Allen  2023-05-08             8716
# 2664   property      741696         Jack Walker  2023-06-02             8965
# ...         ...         ...                 ...         ...              ...
# 2210   property      462779   Charlotte Jackson  2023-01-24             1471
# 14144    health      534443       William Allen  2022-08-21             4690
# 23108    health      750239        Elijah White  2022-09-29             7323
# 25703      auto      252408   Sebastian Jackson  2023-03-12             7733
# 29171    health      372671      Sophia Jackson  2022-07-15             1753
#
#                                                     text  claim_amount  \
# 2308   An alarming incident involving a shopping mall...          4978
# 22404  On 2023-01-17 , Charlotte Anderson encountered...         39122
# 23397  A distressing [ Property Incident 34 ] took pl...         93664
# 25058  There wa a significant puncture incident on 20...         90715
# 2664   A distressing incident took place on 2023-06-0...         55454
# ...                                                  ...           ...
# 2210   On 2023-01-24 , a critical [ Property Incident...          9732
# 14144  There wa a car accident incident on 2022-08-21...          7388
# 23108  There wa a heart attack incident on 2022-09-29...         30633
# 25703  On 2023-03-12 , Vehicle W encountered a mechan...         59718
# 29171  A significant spinal injury incident took plac...         52115
#
#       claim_status                              communication_history  \
# 2308      Approved  I am seeking reimbursement for the repair and ...
# 22404      Pending  Please provide additional information regardin...
# 23397       Denied  I need assistance with documenting and itemizi...
# 25058  In Progress  Kindly provide a detailed account of the healt...
# 2664   In Progress  I am writing to report a property incident and...
# ...            ...                                                ...
# 2210      Approved  I need to submit a property insurance claim du...
# 14144       Denied  Kindly provide a detailed account of the healt...
# 23108      Pending  Kindly provide a detailed account of the healt...
# 25703     Approved  I request a comprehensive report on the auto i...
# 29171       Denied  It is essential to gather all pertinent inform...
#
#        encoded_label
# 2308               2
# 22404              1
# 23397              2
# 25058              1
# 2664               2
# ...              ...
# 2210               2
# 14144              1
# 23108              1
# 25703              0
# 29171              1
#
# [6000 rows x 10 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
# Convert your train and test text data to lists
train_texts = train["text"].tolist()
test_texts = test["text"].tolist()

# Initialize the tokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

train_encodings = tokenizer(
    train_texts,
    padding=True,
    max_length=12,
    return_tensors="pt",
    truncation=True
)

test_encodings = tokenizer(
    test_texts,
    padding=True,
    max_length=12,
    return_tensors="pt",
    truncation=True
)

# %% [markdown]
# ## Generate Pretrained BERT Embeddings

# %%
import torch

batch_size = 4
train_embeddings = []
test_embeddings = []

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Get the GPU device on which we run our experiments
gpu_name = torch.cuda.get_device_name(device) if device.type == 'cuda' else 'N/A'
print("GPU Device:", gpu_name)


model = BertModel.from_pretrained('bert-base-uncased')
model = model.to(device)

with torch.no_grad():
    for i in range(0, len(train_encodings['input_ids']), batch_size):
        batch_tokens = {key: val[i:i+batch_size] for key, val in train_encodings.items()}
        batch_tokens = {key: torch.tensor(val).to(device) for key, val in batch_tokens.items()}
        batch_outputs = model(**batch_tokens)
        batch_embeddings = batch_outputs.last_hidden_state[:, 0, :].to('cpu')  # Move back to CPU temporarily
        train_embeddings.append(batch_embeddings.to(device))  # Move to CUDA device

    for i in range(0, len(test_encodings['input_ids']), batch_size):
        batch_tokens = {key: val[i:i+batch_size] for key, val in test_encodings.items()}
        batch_tokens = {key: torch.tensor(val).to(device) for key, val in batch_tokens.items()}
        batch_outputs = model(**batch_tokens)
        batch_embeddings = batch_outputs.last_hidden_state[:, 0, :].to('cpu')  # Move back to CPU temporarily
        test_embeddings.append(batch_embeddings.to(device))  # Move to CUDA device

train_embeddings = torch.cat(train_embeddings, dim=0).to('cpu')  # Move back to CPU
test_embeddings = torch.cat(test_embeddings, dim=0).to('cpu')  # Move back to CPU

print('train embd shape:', train_embeddings.shape, 'test embd shape:', test_embeddings.shape)
# Out:
# GPU Device: NVIDIA GeForce RTX 3070 Laptop GPU
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /tmp/ipykernel_32225/3828806100.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_tokens = {key: torch.tensor(val).to(device) for key, val in batch_tokens.items()}
# /tmp/ipykernel_32225/3828806100.py:27: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_tokens = {key: torch.tensor(val).to(device) for key, val in batch_tokens.items()}
# train embd shape: torch.Size([24000, 768]) test embd shape: torch.Size([6000, 768])

# %% [markdown]
# ## XGBoost Classifier for Claim Category Classification

# %%
from sklearn.model_selection import train_test_split
import xgboost as xgb

train_labels=train.encoded_label.to_list()

# Split the data into train and validation sets
train_embeddings1, val_embeddings1, train_labels1, val_labels1 = train_test_split(train_embeddings, 
                                                                                  train_labels, 
                                                                                  test_size=0.2, 
                                                                                  random_state=42)
print("train data shape: ", train_embeddings1.shape, "validation data shape: ", val_embeddings1.shape)
# Out:
# train data shape:  torch.Size([19200, 768]) validation data shape:  torch.Size([4800, 768])

# %%
import numpy as np
import xgboost as xgb
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# Convert the encoded labels to NumPy arrays
train_labels = train['encoded_label'].values
test_labels = test['encoded_label'].values

# Convert Torch tensors to NumPy arrays
train_embeddings1_np = train_embeddings1.detach().cpu().numpy()
val_embeddings1_np = val_embeddings1.detach().cpu().numpy()
train_labels1_np = train_labels1
val_labels1_np = val_labels1

# Initialize the XGBoost Classifier
xgb_classifier = xgb.XGBClassifier(n_estimators=150, learning_rate=0.02)
eval_set = (
    (train_embeddings1_np, train_labels1_np),
    (val_embeddings1_np, val_labels1_np)
)
xgb_classifier.fit(
    train_embeddings1_np,
    train_labels1_np,
    eval_metric="merror",
    eval_set=eval_set
)


# Make predictions on the training set
train_preds = xgb_classifier.predict(train_embeddings1_np)

# Print the classification report and confusion matrix for train data
print("Classification Report - Train Data:")
print(classification_report(train_labels1_np, train_preds, digits=3))
print("Confusion Matrix - Train Data:")
print(confusion_matrix(train_labels1_np, train_preds))




# Make predictions on the validation set
val_preds = xgb_classifier.predict(val_embeddings1_np)

# Print the classification report and confusion matrix for validation data
print("Classification Report - Validation Data:")
print(classification_report(val_labels1_np, val_preds, digits=3))
print("Confusion Matrix - Validation Data:")
print(confusion_matrix(val_labels1_np, val_preds))





# Make predictions on the test set
test_embeddings_np = test_embeddings.detach().cpu().numpy()
test_preds = xgb_classifier.predict(test_embeddings_np)

# Print the classification report and confusion matrix
print("Classification Report - Test Data:")
print(classification_report(test_labels, test_preds, digits=3))
print("Confusion Matrix - Test Data:")
print(confusion_matrix(test_labels, test_preds))
# Out:
# [0]	validation_0-merror:0.04432	validation_1-merror:0.04271
# [1]	validation_0-merror:0.04432	validation_1-merror:0.04271
# [2]	validation_0-merror:0.04432	validation_1-merror:0.04271
# [3]	validation_0-merror:0.04432	validation_1-merror:0.04271
# [4]	validation_0-merror:0.04427	validation_1-merror:0.04271
# [5]	validation_0-merror:0.04422	validation_1-merror:0.04250
# [6]	validation_0-merror:0.04396	validation_1-merror:0.04354
# [7]	validation_0-merror:0.04443	validation_1-merror:0.04208
# [8]	validation_0-merror:0.04412	validation_1-merror:0.04292
# [9]	validation_0-merror:0.04448	validation_1-merror:0.04188
# [10]	validation_0-merror:0.04412	validation_1-merror:0.04208
# [11]	validation_0-merror:0.04229	validation_1-merror:0.04021
# [12]	validation_0-merror:0.04229	validation_1-merror:0.04021
# [13]	validation_0-merror:0.04224	validation_1-merror:0.04063
# [14]	validation_0-merror:0.04219	validation_1-merror:0.04104
# [15]	validation_0-merror:0.04213	validation_1-merror:0.04104
# [16]	validation_0-merror:0.04208	validation_1-merror:0.04083
# [17]	validation_0-merror:0.04193	validation_1-merror:0.04083
# [18]	validation_0-merror:0.04208	validation_1-merror:0.04083
# [19]	validation_0-merror:0.04193	validation_1-merror:0.04146
# [20]	validation_0-merror:0.04167	validation_1-merror:0.04083
# [21]	validation_0-merror:0.04167	validation_1-merror:0.04146
# [22]	validation_0-merror:0.04161	validation_1-merror:0.04146
# [23]	validation_0-merror:0.04141	validation_1-merror:0.04188
# [24]	validation_0-merror:0.04130	validation_1-merror:0.04167
# [25]	validation_0-merror:0.04135	validation_1-merror:0.04146
# [26]	validation_0-merror:0.04120	validation_1-merror:0.04167
# [27]	validation_0-merror:0.04115	validation_1-merror:0.04167
# [28]	validation_0-merror:0.04083	validation_1-merror:0.04146
# [29]	validation_0-merror:0.04078	validation_1-merror:0.04125
# [30]	validation_0-merror:0.04063	validation_1-merror:0.04104
# [31]	validation_0-merror:0.04042	validation_1-merror:0.04104
# [32]	validation_0-merror:0.04026	validation_1-merror:0.04083
# [33]	validation_0-merror:0.04042	validation_1-merror:0.04063
# [34]	validation_0-merror:0.04036	validation_1-merror:0.04083
# [35]	validation_0-merror:0.04042	validation_1-merror:0.04083
# [36]	validation_0-merror:0.04026	validation_1-merror:0.04083
# [37]	validation_0-merror:0.04005	validation_1-merror:0.04083
# [38]	validation_0-merror:0.04000	validation_1-merror:0.04104
# [39]	validation_0-merror:0.03990	validation_1-merror:0.04063
# [40]	validation_0-merror:0.03984	validation_1-merror:0.04083
# [41]	validation_0-merror:0.03979	validation_1-merror:0.04083
# [42]	validation_0-merror:0.03974	validation_1-merror:0.04083
# [43]	validation_0-merror:0.03969	validation_1-merror:0.04083
# [44]	validation_0-merror:0.03927	validation_1-merror:0.04125
# [45]	validation_0-merror:0.03922	validation_1-merror:0.04083
# [46]	validation_0-merror:0.03922	validation_1-merror:0.04146
# [47]	validation_0-merror:0.03917	validation_1-merror:0.04125
# [48]	validation_0-merror:0.03906	validation_1-merror:0.04104
# [49]	validation_0-merror:0.03891	validation_1-merror:0.04104
# [50]	validation_0-merror:0.03870	validation_1-merror:0.04083
# [51]	validation_0-merror:0.03859	validation_1-merror:0.04083
# [52]	validation_0-merror:0.03844	validation_1-merror:0.04083
# [53]	validation_0-merror:0.03828	validation_1-merror:0.04125
# [54]	validation_0-merror:0.03802	validation_1-merror:0.04167
# [55]	validation_0-merror:0.03802	validation_1-merror:0.04188
# [56]	validation_0-merror:0.03797	validation_1-merror:0.04208
# [57]	validation_0-merror:0.03792	validation_1-merror:0.04208
# [58]	validation_0-merror:0.03776	validation_1-merror:0.04208
# [59]	validation_0-merror:0.03771	validation_1-merror:0.04188
# [60]	validation_0-merror:0.03771	validation_1-merror:0.04188
# [61]	validation_0-merror:0.03776	validation_1-merror:0.04188
# [62]	validation_0-merror:0.03776	validation_1-merror:0.04188
# [63]	validation_0-merror:0.03776	validation_1-merror:0.04188
# [64]	validation_0-merror:0.03750	validation_1-merror:0.04208
# [65]	validation_0-merror:0.03745	validation_1-merror:0.04208
# [66]	validation_0-merror:0.03724	validation_1-merror:0.04229
# [67]	validation_0-merror:0.03677	validation_1-merror:0.04271
# [68]	validation_0-merror:0.03693	validation_1-merror:0.04271
# [69]	validation_0-merror:0.03682	validation_1-merror:0.04271
# [70]	validation_0-merror:0.03682	validation_1-merror:0.04271
# [71]	validation_0-merror:0.03682	validation_1-merror:0.04250
# [72]	validation_0-merror:0.03682	validation_1-merror:0.04250
# [73]	validation_0-merror:0.03667	validation_1-merror:0.04250
# [74]	validation_0-merror:0.03672	validation_1-merror:0.04250
# [75]	validation_0-merror:0.03667	validation_1-merror:0.04250
# [76]	validation_0-merror:0.03667	validation_1-merror:0.04250
# [77]	validation_0-merror:0.03651	validation_1-merror:0.04250
# [78]	validation_0-merror:0.03646	validation_1-merror:0.04208
# [79]	validation_0-merror:0.03646	validation_1-merror:0.04208
# [80]	validation_0-merror:0.03646	validation_1-merror:0.04188
# [81]	validation_0-merror:0.03635	validation_1-merror:0.04188
# [82]	validation_0-merror:0.03615	validation_1-merror:0.04229
# [83]	validation_0-merror:0.03625	validation_1-merror:0.04229
# [84]	validation_0-merror:0.03620	validation_1-merror:0.04208
# [85]	validation_0-merror:0.03620	validation_1-merror:0.04188
# [86]	validation_0-merror:0.03609	validation_1-merror:0.04188
# [87]	validation_0-merror:0.03609	validation_1-merror:0.04188
# [88]	validation_0-merror:0.03599	validation_1-merror:0.04188
# [89]	validation_0-merror:0.03589	validation_1-merror:0.04188
# [90]	validation_0-merror:0.03589	validation_1-merror:0.04188
# [91]	validation_0-merror:0.03589	validation_1-merror:0.04188
# [92]	validation_0-merror:0.03589	validation_1-merror:0.04167
# [93]	validation_0-merror:0.03589	validation_1-merror:0.04167
# [94]	validation_0-merror:0.03589	validation_1-merror:0.04167
# [95]	validation_0-merror:0.03578	validation_1-merror:0.04208
# [96]	validation_0-merror:0.03573	validation_1-merror:0.04208
# [97]	validation_0-merror:0.03552	validation_1-merror:0.04208
# [98]	validation_0-merror:0.03552	validation_1-merror:0.04188
# [99]	validation_0-merror:0.03552	validation_1-merror:0.04188
# [100]	validation_0-merror:0.03552	validation_1-merror:0.04188
# [101]	validation_0-merror:0.03552	validation_1-merror:0.04188
# [102]	validation_0-merror:0.03547	validation_1-merror:0.04167
# [103]	validation_0-merror:0.03552	validation_1-merror:0.04167
# [104]	validation_0-merror:0.03552	validation_1-merror:0.04167
# [105]	validation_0-merror:0.03531	validation_1-merror:0.04167
# [106]	validation_0-merror:0.03531	validation_1-merror:0.04167
# [107]	validation_0-merror:0.03537	validation_1-merror:0.04146
# [108]	validation_0-merror:0.03526	validation_1-merror:0.04146
# [109]	validation_0-merror:0.03526	validation_1-merror:0.04146
# [110]	validation_0-merror:0.03526	validation_1-merror:0.04146
# [111]	validation_0-merror:0.03526	validation_1-merror:0.04146
# [112]	validation_0-merror:0.03537	validation_1-merror:0.04146
# [113]	validation_0-merror:0.03516	validation_1-merror:0.04146
# [114]	validation_0-merror:0.03510	validation_1-merror:0.04146
# [115]	validation_0-merror:0.03510	validation_1-merror:0.04146
# [116]	validation_0-merror:0.03510	validation_1-merror:0.04146
# [117]	validation_0-merror:0.03510	validation_1-merror:0.04146
# [118]	validation_0-merror:0.03510	validation_1-merror:0.04146
# [119]	validation_0-merror:0.03505	validation_1-merror:0.04125
# [120]	validation_0-merror:0.03500	validation_1-merror:0.04146
# [121]	validation_0-merror:0.03510	validation_1-merror:0.04167
# [122]	validation_0-merror:0.03510	validation_1-merror:0.04167
# [123]	validation_0-merror:0.03510	validation_1-merror:0.04167
# [124]	validation_0-merror:0.03510	validation_1-merror:0.04167
# [125]	validation_0-merror:0.03521	validation_1-merror:0.04167
# [126]	validation_0-merror:0.03531	validation_1-merror:0.04167
# [127]	validation_0-merror:0.03531	validation_1-merror:0.04167
# [128]	validation_0-merror:0.03531	validation_1-merror:0.04167
# [129]	validation_0-merror:0.03526	validation_1-merror:0.04167
# [130]	validation_0-merror:0.03521	validation_1-merror:0.04167
# [131]	validation_0-merror:0.03526	validation_1-merror:0.04167
# [132]	validation_0-merror:0.03531	validation_1-merror:0.04188
# [133]	validation_0-merror:0.03531	validation_1-merror:0.04188
# [134]	validation_0-merror:0.03531	validation_1-merror:0.04188
# [135]	validation_0-merror:0.03542	validation_1-merror:0.04188
# [136]	validation_0-merror:0.03537	validation_1-merror:0.04188
# [137]	validation_0-merror:0.03537	validation_1-merror:0.04188
# [138]	validation_0-merror:0.03537	validation_1-merror:0.04188
# [139]	validation_0-merror:0.03531	validation_1-merror:0.04188
# [140]	validation_0-merror:0.03537	validation_1-merror:0.04188
# [141]	validation_0-merror:0.03537	validation_1-merror:0.04188
# [142]	validation_0-merror:0.03537	validation_1-merror:0.04188
# [143]	validation_0-merror:0.03531	validation_1-merror:0.04188
# [144]	validation_0-merror:0.03531	validation_1-merror:0.04188
# [145]	validation_0-merror:0.03531	validation_1-merror:0.04188
# [146]	validation_0-merror:0.03531	validation_1-merror:0.04188
# [147]	validation_0-merror:0.03531	validation_1-merror:0.04188
# [148]	validation_0-merror:0.03531	validation_1-merror:0.04188
# [149]	validation_0-merror:0.03531	validation_1-merror:0.04188
# Classification Report - Train Data:
#               precision    recall  f1-score   support
#
#            0      0.957     0.945     0.951      6512
#            1      0.940     0.967     0.953      6346
#            2      0.999     0.983     0.991      6342
#
#     accuracy                          0.965     19200
#    macro avg      0.965     0.965     0.965     19200
# weighted avg      0.965     0.965     0.965     19200
#
# Confusion Matrix - Train Data:
# [[6151  356    5]
#  [ 203 6139    4]
#  [  74   36 6232]]
# Classification Report - Validation Data:
#               precision    recall  f1-score   support
#
#            0      0.942     0.942     0.942      1628
#            1      0.936     0.956     0.946      1608
#            2      0.999     0.977     0.988      1564
#
#     accuracy                          0.958      4800
#    macro avg      0.959     0.958     0.959      4800
# weighted avg      0.959     0.958     0.958      4800
#
# Confusion Matrix - Validation Data:
# [[1533   94    1]
#  [  69 1538    1]
#  [  25   11 1528]]
# Classification Report - Test Data:
#               precision    recall  f1-score   support
#
#            0      0.942     0.931     0.937      2040
#            1      0.930     0.956     0.943      1992
#            2      0.994     0.978     0.986      1968
#
#     accuracy                          0.955      6000
#    macro avg      0.956     0.955     0.955      6000
# weighted avg      0.955     0.955     0.955      6000
#
# Confusion Matrix - Test Data:
# [[1900  133    7]
#  [  83 1905    4]
#  [  33   10 1925]]

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt
import seaborn as sns
# # Calculate evaluation metrics
# accuracy = accuracy_score(test_labels, test_preds)
# precision = precision_score(test_labels, test_preds, average='macro')
# recall = recall_score(test_labels, test_preds, average='macro')


# Fetch the evaluation results
eval_results = xgb_classifier.evals_result()

# Read the merror values
train_merror = eval_results['validation_0']['merror']
val_merror = eval_results['validation_1']['merror']

# Plot the merror values
plt.figure(figsize=(10, 6))
plt.plot(train_merror, label='Train')
plt.plot(val_merror, label='Validation')
plt.xlabel('Boosting Round')
plt.ylabel('merror')
plt.title('Train and Validation merror')
plt.legend()
plt.show()
